# %%
import requests
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, DistilBertModel
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# ✅ GPU 사용 여부 확인
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("✅ 실행 장치:", device)

# ✅ 배치 크기 증가 (16 → 32)
BATCH_SIZE = 32

# ✅ Fact Check API 캐싱 적용
fact_check_cache = {}

def check_fact_with_api(query):
    """Google Fact Check API를 이용해 뉴스의 진위 여부를 확인 (캐싱 적용)"""
    if query in fact_check_cache:
        return fact_check_cache[query]

    params = {"query": query, "key": "AIzaSyDW8TNNxSZG2NXzA3HGK-19PDBp0jjoOu0"}
    response = requests.get("https://factchecktools.googleapis.com/v1alpha1/claims:search", params=params)
    
    if response.status_code == 200:
        data = response.json()
        claims = data.get("claims", [])
        fact_check_cache[query] = claims
        return claims

    fact_check_cache[query] = []
    return []

# ✅ 데이터 로드
df = pd.read_csv("C:/FakeNewsProject/FakeNews_py/News_Dataset.csv")
tokenizer = AutoTokenizer.from_pretrained('distilbert-base-uncased')

class NewsDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=512):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len
    
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, index):
        text = self.texts[index]
        label = self.labels[index]

        # ✅ Fact Check API 캐싱 활용
        fact_check_results = check_fact_with_api(text)
        fact_check_score = len(fact_check_results)

        encoding = self.tokenizer(
            text,
            truncation=True,
            padding='max_length',
            max_length=self.max_len,
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].squeeze(0),
            'attention_mask': encoding['attention_mask'].squeeze(0),
            'fact_check_score': torch.tensor(fact_check_score, dtype=torch.float),
            'label': torch.tensor(label, dtype=torch.long)
        }

train_texts, test_texts, train_labels, test_labels = train_test_split(
    df['Content'].values, df['Label'].values, test_size=0.2, random_state=42
)

train_dataset = NewsDataset(train_texts, train_labels, tokenizer)
test_dataset = NewsDataset(test_texts, test_labels, tokenizer)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# ✅ GRU 적용 (LSTM보다 빠름)
class FakeNewsDetector(nn.Module):
    def __init__(self, hidden_dim=128, num_classes=2):
        super(FakeNewsDetector, self).__init__()
        self.bert = DistilBertModel.from_pretrained("distilbert-base-uncased")
        self.gru = nn.GRU(768, hidden_dim, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2 + 1, num_classes)
        self.dropout = nn.Dropout(0.3)
    
    def forward(self, input_ids, attention_mask, fact_check_score):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        gru_out, _ = self.gru(outputs.last_hidden_state)
        out = self.dropout(gru_out[:, -1, :])
        out = torch.cat((out, fact_check_score.unsqueeze(1)), dim=1)
        return self.fc(out)

model = FakeNewsDetector().to(device)
optimizer = optim.Adam(model.parameters(), lr=5e-5)  # ✅ 학습률 증가

# 손실 함수 및 평가 메트릭 정의
criterion = nn.CrossEntropyLoss()

def train_model(model, train_loader, test_loader, optimizer, device, epochs=5):
    train_losses, test_losses = [], []
    train_accuracies, test_accuracies = [], []
    
    for epoch in range(epochs):
        model.train()
        total_loss, correct, total = 0, 0, 0

        # 🔹 훈련 (Training)
        for batch in train_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            fact_check_score = batch['fact_check_score'].to(device)
            labels = batch['label'].to(device)

            optimizer.zero_grad()
            outputs = model(input_ids, attention_mask, fact_check_score)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            correct += (outputs.argmax(1) == labels).sum().item()
            total += labels.size(0)

        train_losses.append(total_loss / len(train_loader))
        train_accuracies.append(correct / total)

        # 🔹 검증 (Validation)
        model.eval()
        total_loss, correct, total = 0, 0, 0

        with torch.no_grad():
            for batch in test_loader:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                fact_check_score = batch['fact_check_score'].to(device)
                labels = batch['label'].to(device)

                outputs = model(input_ids, attention_mask, fact_check_score)
                loss = criterion(outputs, labels)

                total_loss += loss.item()
                correct += (outputs.argmax(1) == labels).sum().item()
                total += labels.size(0)

        test_losses.append(total_loss / len(test_loader))
        test_accuracies.append(correct / total)

        print(f"Epoch {epoch+1}/{epochs}")
        print(f"Train Loss: {train_losses[-1]:.4f}, Train Accuracy: {train_accuracies[-1]:.4f}")
        print(f"Test Loss: {test_losses[-1]:.4f}, Test Accuracy: {test_accuracies[-1]:.4f}")
        print("-" * 50)
    
    return train_losses, test_losses, train_accuracies, test_accuracies

# ✅ 학습 실행
train_losses, test_losses, train_accuracies, test_accuracies = train_model(
    model, train_loader, test_loader, optimizer, device, epochs=5
)
# Out:
# ✅ 실행 장치: cpu
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 162
#     159     return train_losses, test_losses, train_accuracies, test_accuracies
#     161 # ✅ 학습 실행
# --> 162 train_losses, test_losses, train_accuracies, test_accuracies = train_model(
#     163     model, train_loader, test_loader, optimizer, device, epochs=5
#     164 )
#
# Cell In[4], line 121, in train_model(model, train_loader, test_loader, optimizer, device, epochs)
#     118 labels = batch['label'].to(device)
#     120 optimizer.zero_grad()
# --> 121 outputs = model(input_ids, attention_mask, fact_check_score)
#     122 loss = criterion(outputs, labels)
#     123 loss.backward()
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[4], line 93, in FakeNewsDetector.forward(self, input_ids, attention_mask, fact_check_score)
#      92 def forward(self, input_ids, attention_mask, fact_check_score):
# ---> 93     outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
#      94     gru_out, _ = self.gru(outputs.last_hidden_state)
#      95     out = self.dropout(gru_out[:, -1, :])
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Python310\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:797, in DistilBertModel.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     792     if self._use_sdpa and head_mask_is_none and not output_attentions:
#     793         attention_mask = _prepare_4d_attention_mask_for_sdpa(
#     794             attention_mask, embeddings.dtype, tgt_len=input_shape[1]
#     795         )
# --> 797 return self.transformer(
#     798     x=embeddings,
#     799     attn_mask=attention_mask,
#     800     head_mask=head_mask,
#     801     output_attentions=output_attentions,
#     802     output_hidden_states=output_hidden_states,
#     803     return_dict=return_dict,
#     804 )
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Python310\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:550, in Transformer.forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     542     layer_outputs = self._gradient_checkpointing_func(
#     543         layer_module.__call__,
#     544         hidden_state,
#    (...)
#     547         output_attentions,
#     548     )
#     549 else:
# --> 550     layer_outputs = layer_module(
#     551         hidden_state,
#     552         attn_mask,
#     553         head_mask[i],
#     554         output_attentions,
#     555     )
#     557 hidden_state = layer_outputs[-1]
#     559 if output_attentions:
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Python310\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:494, in TransformerBlock.forward(self, x, attn_mask, head_mask, output_attentions)
#     491 sa_output = self.sa_layer_norm(sa_output + x)  # (bs, seq_length, dim)
#     493 # Feed Forward Network
# --> 494 ffn_output = self.ffn(sa_output)  # (bs, seq_length, dim)
#     495 ffn_output: torch.Tensor = self.output_layer_norm(ffn_output + sa_output)  # (bs, seq_length, dim)
#     497 output = (ffn_output,)
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Python310\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:428, in FFN.forward(self, input)
#     427 def forward(self, input: torch.Tensor) -> torch.Tensor:
# --> 428     return apply_chunking_to_forward(self.ff_chunk, self.chunk_size_feed_forward, self.seq_len_dim, input)
#
# File c:\Python310\lib\site-packages\transformers\pytorch_utils.py:260, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     257     # concatenate output at same dimension
#     258     return torch.cat(output_chunks, dim=chunk_dim)
# --> 260 return forward_fn(*input_tensors)
#
# File c:\Python310\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:433, in FFN.ff_chunk(self, input)
#     431 x = self.lin1(input)
#     432 x = self.activation(x)
# --> 433 x = self.lin2(x)
#     434 x = self.dropout(x)
#     435 return x
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Python310\lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
